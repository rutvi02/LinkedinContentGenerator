# %% [markdown]
# # Requirements

# %%
import pandas as pd

# %% [markdown]
# # Function to extract all the fields from json file

# %%
def flatten_linkedin_post(post):
    return {
        "urn": post.get("urn"),
        "text": post.get("text"),
        "url": post.get("url"),
        "date": post.get("posted_at", {}).get("date"),
        "relative_time": post.get("posted_at", {}).get("relative"),
        "timestamp": post.get("posted_at", {}).get("timestamp"),
        "author_first_name": post.get("author", {}).get("first_name"),
        "author_last_name": post.get("author", {}).get("last_name"),
        "author_headline": post.get("author", {}).get("headline"),
        "author_username": post.get("author", {}).get("username"),
        "author_profile_url": post.get("author", {}).get("profile_url"),
        "author_profile_picture": post.get("author", {}).get("profile_picture"),
        "likes": post.get("stats", {}).get("like"),
        "support": post.get("stats", {}).get("support"),
        "love": post.get("stats", {}).get("love"),
        "insight": post.get("stats", {}).get("insight"),
        "celebrate": post.get("stats", {}).get("celebrate"),
        "comments": post.get("stats", {}).get("comments"),
        "reposts": post.get("stats", {}).get("reposts"),
        "total_reactions": post.get("stats", {}).get("total_reactions"),
        "media_type": post.get("media", {}).get("type"),
        "media_url": post.get("media", {}).get("url"),
        "media_image_url": post.get("media", {}).get("images", [{}])[0].get("url") if post.get("media") else None,
        "media_image_width": post.get("media", {}).get("images", [{}])[0].get("width") if post.get("media") else None,
        "media_image_height": post.get("media", {}).get("images", [{}])[0].get("height") if post.get("media") else None,
        "pagination_token": post.get("pagination_token")
    }

# %% [markdown]
# # Archit's Data

# %%
with open('ArchitAnand.json', 'r') as f:
    posts = json.load(f)

# Flatten all posts
flattened_posts = [flatten_linkedin_post(post) for post in posts]

# Convert to DataFrame
df = pd.DataFrame(flattened_posts)

# Save to CSV
df.to_csv("ArchitAnand.csv", index=False)

archit = pd.read_csv('ArchitAnand.csv')

# %%
archit.head()
# Out:
#                    urn                                               text  \
# 0  7319156748294971393  “Will AI replace creatives?”\n\nNot until clie...
# 1  7318708509640953856  Ad I loved recently:\n\nNike’s “Someday is not...
# 2  7317970855567785986  Your most viral influencer? Probably made you ...
# 3  7317637438019940353  Is Your Meta Ads Budget Going to Waste?\n\nWe’...
# 4  7316573715591254016  Had to repost this one by Radha Vyas 🙌\n\nWork...
#
#                                                  url                 date  \
# 0  https://www.linkedin.com/posts/archit-anand_cr...  2025-04-19 02:35:52
# 1  https://www.linkedin.com/posts/archit-anand_ad...  2025-04-17 20:54:43
# 2  https://www.linkedin.com/posts/archit-anand_pe...  2025-04-15 20:03:33
# 3  https://www.linkedin.com/posts/archit-anand_fi...  2025-04-14 21:58:40
# 4  https://www.linkedin.com/posts/archit-anand_ar...  2025-04-11 23:31:49
#
#                                        relative_time      timestamp  \
# ...

# %%
archit['text'][0]
# Out:
# '“Will AI replace creatives?”\n\nNot until clients can accurately describe what they want 😅\n \n\nSo yes — creatives, you’re safe.\n(And to be clear: we’re not trying to replace you either.)\n\nBecause creative isn’t just a nice-to-have — it’s the #1 performance lever for brands.\n\n\nAt Fuelgrowth, we’ve seen this over and over again:\n → Brands don’t fail because of bad media buying\n → They fail because they never found the right creative system\n\n\nSo this week, I’m sharing what we’ve learned from auditing 100+ ad accounts —\n The real reasons ROAS drops\n The hidden fatigue patterns\n \n\nAnd how we use AI to spot winning concepts before they scale\n\n\nIf you run ads, lead performance, or are just tired of guesswork —\n\nThis one’s for you.\n\nStay tuned and follow for more✌️\n (No breakdowns, just better systems.)\n\nDrop “ads” below and I’ll send you the invite (must be connected)\n\n#CreativeStrategy #MetaAds #PerformanceMarketing #Fuelgrowth #GrowthSystems #MarketingAI #DT
# ...

# %%
for index, row in archit.iterrows():
    if row['author_first_name'] != 'Archit':
        archit.at[index, 'is_repost'] = 'Yes'
    else:
        archit.at[index, 'is_repost'] = 'No'

# %%
archit.head()
# Out:
#                    urn                                               text  \
# 0  7319156748294971393  “Will AI replace creatives?”\n\nNot until clie...
# 1  7318708509640953856  Ad I loved recently:\n\nNike’s “Someday is not...
# 2  7317970855567785986  Your most viral influencer? Probably made you ...
# 3  7317637438019940353  Is Your Meta Ads Budget Going to Waste?\n\nWe’...
# 4  7316573715591254016  Had to repost this one by Radha Vyas 🙌\n\nWork...
#
#                                                  url                 date  \
# 0  https://www.linkedin.com/posts/archit-anand_cr...  2025-04-19 02:35:52
# 1  https://www.linkedin.com/posts/archit-anand_ad...  2025-04-17 20:54:43
# 2  https://www.linkedin.com/posts/archit-anand_pe...  2025-04-15 20:03:33
# 3  https://www.linkedin.com/posts/archit-anand_fi...  2025-04-14 21:58:40
# 4  https://www.linkedin.com/posts/archit-anand_ar...  2025-04-11 23:31:49
#
#                                        relative_time      timestamp  \
# ...

# %% [markdown]
# # Aaron's Data

# %%
with open('AaronGoblin.json', 'r') as f:
    posts = json.load(f)

# Flatten all posts
flattened_posts = [flatten_linkedin_post(post) for post in posts]

# Convert to DataFrame
df = pd.DataFrame(flattened_posts)

# Save to CSV
df.to_csv("linkedin_aaron.csv", index=False)

aaron = pd.read_csv('linkedin_aaron.csv')

# %%
aaron.head()
# Out:
#                    urn                                               text  \
# 0  7317964602087006208  VCs, CPG investors, and consumer brand founder...
# 1  7317606291844059136  🚨 Are you raising a Pre-Seed or Seed Round? I ...
# 2  7316512091039805440  🚀 What We Look for in Startups at LvlUp Ventur...
# 3  7315859060967313408  Do you want access to a database of 900+ Verif...
# 4  7315713532581351425  🌅 We are excited to announce Scalafai has been...
#
#                                                  url                 date  \
# 0  https://www.linkedin.com/posts/lvlup-vc_east-h...  2025-04-15 19:38:42
# 1  https://www.linkedin.com/posts/adam-ned-0569ab...  2025-04-14 19:54:54
# 2  https://www.linkedin.com/posts/lvlup-vc_fundin...  2025-04-11 19:26:56
# 3  https://www.linkedin.com/posts/aarongolbin_lvl...  2025-04-10 00:12:02
# 4  https://www.linkedin.com/posts/scalafai_future...  2025-04-09 14:33:45
#
#                                        relative_time      timestamp  \
# ...

# %%
for index, row in aaron.iterrows():
    if row['author_first_name'] != 'Aaron':
        aaron.at[index, 'is_repost'] = 'Yes'
    else:
        aaron.at[index, 'is_repost'] = 'No'

# %%
aaron.head()
# Out:
#                    urn                                               text  \
# 0  7317964602087006208  VCs, CPG investors, and consumer brand founder...
# 1  7317606291844059136  🚨 Are you raising a Pre-Seed or Seed Round? I ...
# 2  7316512091039805440  🚀 What We Look for in Startups at LvlUp Ventur...
# 3  7315859060967313408  Do you want access to a database of 900+ Verif...
# 4  7315713532581351425  🌅 We are excited to announce Scalafai has been...
#
#                                                  url                 date  \
# 0  https://www.linkedin.com/posts/lvlup-vc_east-h...  2025-04-15 19:38:42
# 1  https://www.linkedin.com/posts/adam-ned-0569ab...  2025-04-14 19:54:54
# 2  https://www.linkedin.com/posts/lvlup-vc_fundin...  2025-04-11 19:26:56
# 3  https://www.linkedin.com/posts/aarongolbin_lvl...  2025-04-10 00:12:02
# 4  https://www.linkedin.com/posts/scalafai_future...  2025-04-09 14:33:45
#
#                                        relative_time      timestamp  \
# ...

# %% [markdown]
# # Robert's data

# %%
with open('RobertSchone.json', 'r') as f:
    posts = json.load(f)

# Flatten all posts
flattened_posts = [flatten_linkedin_post(post) for post in posts]

# Convert to DataFrame
df = pd.DataFrame(flattened_posts)

# Save to CSV
df.to_csv("linkedin_robert.csv", index=False)

robert = pd.read_csv('linkedin_robert.csv')

# %%
robert.head()
# Out:
#                    urn                                               text  \
# 0  7318920503841214464  For my german speaking community:\nWir sind mi...
# 1  7317819071276724226  BIG TECH’S AI BETS - are we back on (AI) track...
# 2  7317629841674035200  👀 10 questions every executive team should be ...
# 3  7317425161295601664  The Secret to growing your audience and turnin...
# 4  7316009323875229697  Yesterday, I learned I‘m living in another rea...
#
#                                                  url                 date  \
# 0  https://www.linkedin.com/posts/steffikieffer_b...  2025-04-18 10:57:07
# 1  https://www.linkedin.com/posts/robertsch%C3%B6...  2025-04-15 10:00:25
# 2  https://www.linkedin.com/posts/board-of-innova...  2025-04-14 21:28:29
# 3  https://www.linkedin.com/posts/robertsch%C3%B6...  2025-04-14 07:55:09
# 4  https://www.linkedin.com/posts/robertsch%C3%B6...  2025-04-10 10:09:07
#
#                                        relative_time      timestamp  \
# ...

# %%
for index, row in robert.iterrows():
    if row['author_first_name'] != 'Robert':
        robert.at[index, 'is_repost'] = 'Yes'
    else:
        robert.at[index, 'is_repost'] = 'No'

# %%
robert.head()
# Out:
#                    urn                                               text  \
# 0  7318920503841214464  For my german speaking community:\nWir sind mi...
# 1  7317819071276724226  BIG TECH’S AI BETS - are we back on (AI) track...
# 2  7317629841674035200  👀 10 questions every executive team should be ...
# 3  7317425161295601664  The Secret to growing your audience and turnin...
# 4  7316009323875229697  Yesterday, I learned I‘m living in another rea...
#
#                                                  url                 date  \
# 0  https://www.linkedin.com/posts/steffikieffer_b...  2025-04-18 10:57:07
# 1  https://www.linkedin.com/posts/robertsch%C3%B6...  2025-04-15 10:00:25
# 2  https://www.linkedin.com/posts/board-of-innova...  2025-04-14 21:28:29
# 3  https://www.linkedin.com/posts/robertsch%C3%B6...  2025-04-14 07:55:09
# 4  https://www.linkedin.com/posts/robertsch%C3%B6...  2025-04-10 10:09:07
#
#                                        relative_time      timestamp  \
# ...

# %% [markdown]
# # Jaspar's data

# %%
with open('Jaspar_Carmichael.json', 'r') as f:
    posts = json.load(f)

# Flatten all posts
flattened_posts = [flatten_linkedin_post(post) for post in posts]

# Convert to DataFrame
df = pd.DataFrame(flattened_posts)

# Save to CSV
df.to_csv("linkedin_jaspar.csv", index=False)

jaspar = pd.read_csv('linkedin_jaspar.csv')

# %%
jaspar.head()
# Out:
#                    urn                                               text  \
# 0  7318676547719073793  We’ve raised over $35M, crossed $5M ARR, gener...
# 1  7317962895504334848  It’s hard to compete with Artisan’s viral camp...
# 2  7317940087839731712  We raised our $25M Series A just 6 months afte...
# 3  7317577074813095937  After announcing our $25M Series A last week, ...
# 4  7317013053240139776  Artisan is one of a bevy of fast-growing start...
#
#                                                  url                 date  \
# 0  https://www.linkedin.com/posts/jaspar-carmicha...  2025-04-17 18:47:43
# 1  https://www.linkedin.com/posts/dashashunina_it...  2025-04-15 19:31:55
# 2  https://www.linkedin.com/posts/jaspar-carmicha...  2025-04-15 18:01:17
# 3  https://www.linkedin.com/posts/jaspar-carmicha...  2025-04-14 17:58:48
# 4  https://www.linkedin.com/posts/techcrunch_tech...  2025-04-13 04:37:35
#
#                                        relative_time      timestamp  \
# ...

# %%
jaspar['is_repost'] = "dont know"

# %%
jaspar.head()
# Out:
#                    urn                                               text  \
# 0  7318676547719073793  We’ve raised over $35M, crossed $5M ARR, gener...
# 1  7317962895504334848  It’s hard to compete with Artisan’s viral camp...
# 2  7317940087839731712  We raised our $25M Series A just 6 months afte...
# 3  7317577074813095937  After announcing our $25M Series A last week, ...
# 4  7317013053240139776  Artisan is one of a bevy of fast-growing start...
#
#                                                  url                 date  \
# 0  https://www.linkedin.com/posts/jaspar-carmicha...  2025-04-17 18:47:43
# 1  https://www.linkedin.com/posts/dashashunina_it...  2025-04-15 19:31:55
# 2  https://www.linkedin.com/posts/jaspar-carmicha...  2025-04-15 18:01:17
# 3  https://www.linkedin.com/posts/jaspar-carmicha...  2025-04-14 17:58:48
# 4  https://www.linkedin.com/posts/techcrunch_tech...  2025-04-13 04:37:35
#
#                                        relative_time      timestamp  \
# ...

# %%
for index, row in jaspar.iterrows():
    if row['author_first_name'] != 'Jaspar':
        jaspar.at[index, 'is_repost'] = 'Yes'
    else:
        jaspar.at[index, 'is_repost'] = 'No'

# %%
jaspar.head()
# Out:
#                    urn                                               text  \
# 0  7318676547719073793  We’ve raised over $35M, crossed $5M ARR, gener...
# 1  7317962895504334848  It’s hard to compete with Artisan’s viral camp...
# 2  7317940087839731712  We raised our $25M Series A just 6 months afte...
# 3  7317577074813095937  After announcing our $25M Series A last week, ...
# 4  7317013053240139776  Artisan is one of a bevy of fast-growing start...
#
#                                                  url                 date  \
# 0  https://www.linkedin.com/posts/jaspar-carmicha...  2025-04-17 18:47:43
# 1  https://www.linkedin.com/posts/dashashunina_it...  2025-04-15 19:31:55
# 2  https://www.linkedin.com/posts/jaspar-carmicha...  2025-04-15 18:01:17
# 3  https://www.linkedin.com/posts/jaspar-carmicha...  2025-04-14 17:58:48
# 4  https://www.linkedin.com/posts/techcrunch_tech...  2025-04-13 04:37:35
#
#                                        relative_time      timestamp  \
# ...

# %% [markdown]
# # Combining All users data

# %%
all_users = [archit, aaron, robert, jaspar]

combined_df = pd.concat(all_users, ignore_index=True)

# %%
combined_df.tail()
# Out:
#                      urn                                               text  \
# 394  7225243341334999040  The top 10 sales intelligence startups you sho...
# 395  7224487754250768384  Artisan has just closed over $700k of ARR in 2...
# 396  7224121327786360832  We've closed ~$700k of ARR within 2 months as ...
# 397  7222288304778428417  Are AI SDRs able to replace humans yet?\n\nAt ...
# 398  7219357180783702016  The lead drought is real and it's killing sale...
#
#                                                    url                 date  \
# 394  https://www.linkedin.com/posts/crustdata_the-t...  2024-08-02 22:57:31
# 395  https://www.linkedin.com/posts/tinasang_artisa...  2024-07-31 20:55:05
# 396  https://www.linkedin.com/posts/jaspar-carmicha...  2024-07-30 20:39:02
# 397  https://www.linkedin.com/posts/jaspar-carmicha...  2024-07-25 19:15:15
# 398  https://www.linkedin.com/posts/jaspar-carmicha...  2024-07-17 17:08:01
#
# ...

# %%
combined_df.to_csv("all_users.csv", index=False)
